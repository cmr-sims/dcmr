# %% [markdown]
# # Plot model fit comparisons for simulation analysis 2

# %%
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from mindstorm import statplot
from dcmr import framework
from dcmr import figures
from dcmr import reports

fit_dir = Path(os.environ['CFR_FITS']) / 'merge'
fig_dir = Path(os.environ['CFR_FIGURES']) / 'sim2'
os.makedirs(fig_dir, exist_ok=True)
figures.set_style()
# %matplotlib inline

# %% [markdown]
# ## Load model fits

# %%
included = ['DCMR', 'DCMR-Variable', 'DCMR-Focused', 'CMR-MP16']
models, model_names = framework.get_sim_models('cfr2', 'set2', included=included)
all_models, all_model_names = framework.get_sim_models('cfr2', 'set1')

# %% [markdown]
# ## Plot model cross-validation performance

# %%
all_xval = framework.read_model_xvals(fit_dir, all_models, all_model_names)
g = figures.plot_xval_comp(all_xval, aspect=1.5, height=5)
g.savefig(fig_dir / 'model_comp_xval_full.pdf');
# Out:
# LINO NOT subset; don't know how to subset; dropped

# %%
xval = framework.read_model_xvals(fit_dir, models, model_names)
g = figures.plot_xval_comp(xval, aspect=1.57, height=4)
g.savefig(fig_dir / 'model_comp_xval_subset.pdf');
# Out:
# LINO NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Plot best-fitting B parameters by sublayer

# %%
dark = sns.color_palette(
    'ch:start=1, rot=1.5, light=.7, dark=.3, gamma=1, hue=.5'
)
dark
# Out:
# [(0.7689335648950519, 0.6824396172757954, 0.6240123846554909),
#  (0.7250187127782463, 0.5677430873950093, 0.6103083104698684),
#  (0.623013021104788, 0.4855809829815538, 0.6161810850461853),
#  (0.464634733019296, 0.4332443294049108, 0.5801730795425324),
#  (0.31355069957273196, 0.3965359745123169, 0.4760973803152319),
#  (0.2050147315167219, 0.34168808481661433, 0.31762490490999895)]

# %%
light = sns.color_palette(
    'ch:start=1, rot=1.5, light=.7, dark=.3, gamma=.5, hue=1'
)
light
# Out:
# [(0.9248203983802259, 0.8124754066629261, 0.7365856230946308),
#  (0.9370151046580671, 0.7134152392755648, 0.773930517001042),
#  (0.8638347057562072, 0.6485629096614572, 0.8531332480304541),
#  (0.6875944308206159, 0.6323388125763083, 0.8909732355818533),
#  (0.4826946089121227, 0.6491392670198295, 0.8087166257388984),
#  (0.325484389760949, 0.649366831333291, 0.5923429764853889)]

# %%
ur_model = all_models[all_model_names.index("UR")]
fit = framework.read_model_fits(fit_dir, [ur_model], ["UR"])
B_names = [
    'B_enc_loc',
    'B_enc_cat',
    'B_enc_use',
    'B_rec_loc',
    'B_rec_cat',
    'B_rec_use',
]
B_subset = pd.melt(
    fit[B_names].reset_index(),
    id_vars='subject', 
    value_vars=B_names,
    var_name='parameter',
    value_name='value',
)
fit[B_names].reset_index()
# Out:
#    model  subject  B_enc_loc  B_enc_cat  B_enc_use  B_rec_loc  B_rec_cat  \
# 0     UR        1   0.758188   0.004332   0.809997   0.904538   1.000000
# 1     UR        2   0.720992   0.008721   0.826419   0.847841   1.000000
# 2     UR        3   0.615264   0.027801   0.547687   0.928677   1.000000
# 3     UR        5   0.552102   0.730554   0.158131   0.581877   1.000000
# 4     UR        8   0.658651   0.649194   0.825556   0.705218   0.980629
# 5     UR       11   0.211437   0.000000   0.740402   0.497423   1.000000
# 6     UR       16   0.623610   0.003247   0.651476   0.759772   1.000000
# 7     UR       18   0.433381   0.000000   0.692895   0.784947   1.000000
# 8     UR       22   0.683614   0.144265   0.804377   0.843294   1.000000
# 9     UR       23   0.610162   0.000000   0.507661   0.860902   1.000000
# 10    UR       24   0.567287   0.002000   0.918438   0.869381   0.966212
# 11    UR       25   0.445369   0.022020   0.007590   0.756368   1.000000
# 12    UR       27   0.399658   0.000000   0.003172   0.747943   1.000000
# 13    UR       28   0.507006   0.000528   0.010867   0.953399   1.000000
# 14    UR       29   0.628381   0.006828   0.926406   0.901652   1.000000
# 15    UR       31   0.682569   0.983019   0.864010   0.714294   1.000000
# 16    UR       32   0.367121   0.000000   0.745385   0.868848   1.000000
# 17    UR       33   0.524159   0.047526   0.042656   0.901253   1.000000
# 18    UR       34   0.406549   0.000000   0.008604   0.685172   1.000000
# 19    UR       35   0.587064   0.459686   0.016949   0.772237   0.964237
# 20    UR       37   0.920025   0.000707   0.322157   0.999481   1.000000
# 21    UR       38   0.790464   0.000000   0.002640   0.868978   1.000000
# 22    UR       40   0.705660   0.001602   0.959172   0.889372   1.000000
# 23    UR       41   0.435248   0.000000   0.765311   0.822702   1.000000
# 24    UR       42   0.452958   0.730691   0.013320   0.842285   1.000000
# 25    UR       43   0.471727   0.139897   0.878381   0.552138   1.000000
# 26    UR       44   0.706904   0.201455   0.088699   0.891799   1.000000
# 27    UR       45   0.648198   0.018376   0.860253   0.790476   1.000000
# 28    UR       46   0.513125   0.000141   0.724807   0.723168   1.000000
#
#     B_rec_use
# 0    0.999618
# 1    0.998979
# 2    0.999701
# 3    1.000000
# 4    1.000000
# 5    1.000000
# 6    1.000000
# 7    1.000000
# 8    1.000000
# 9    0.993770
# 10   0.963546
# 11   1.000000
# 12   1.000000
# 13   1.000000
# 14   1.000000
# 15   1.000000
# 16   0.999987
# 17   1.000000
# 18   1.000000
# 19   1.000000
# 20   0.066313
# 21   1.000000
# 22   0.999554
# 23   1.000000
# 24   1.000000
# 25   1.000000
# 26   1.000000
# 27   1.000000
# 28   1.000000

# %%
B_labels = [
    r'$\beta_\mathrm{enc}^{I}$',
    r'$\beta_\mathrm{enc}^{C}$',
    r'$\beta_\mathrm{enc}^{D}$',
    r'$\beta_\mathrm{rec}^{I}$',
    r'$\beta_\mathrm{rec}^{C}$',
    r'$\beta_\mathrm{rec}^{D}$',
]
B_subset['phase'] = B_subset['parameter'].map(
    {
        'B_enc_loc': 'enc',
        'B_enc_cat': 'enc',
        'B_enc_use': 'enc',
        'B_rec_loc': 'rec',
        'B_rec_cat': 'rec',
        'B_rec_use': 'rec',
    }
)
B_subset['sublayer'] = B_subset['parameter'].map(
    {
        'B_enc_loc': 'I',
        'B_enc_cat': 'C',
        'B_enc_use': 'D',
        'B_rec_loc': 'I',
        'B_rec_cat': 'C',
        'B_rec_use': 'D',
    }
)
fig, ax = plt.subplots(figsize=(6, 4))
statplot.plot_swarm_bar(
    B_subset,
    x='phase',
    y='value',
    hue='sublayer',
    point_kind='strip',
    light=light,
    dark=dark,
    dodge=True,
    bar_kws={'capsize': 0.2, 'clip_on': False},
    point_kws={'size': 4},
    legend=False,
    ax=ax,
)
ax.set(ylim=(0, 1), ylabel='Parameter estimate')
ax.set_xticks(
    [0, 1], 
    [r'$\beta_{enc}$', r'$\beta_{rec}$'], 
    usetex=True, 
    fontfamily='helvetica',
    fontsize='x-large',
)
ax.tick_params(axis='x', length=0)
ax.set(ylim=(0, 1.08), yticks=np.arange(0, 1.2, 0.2))
ax.spines['left'].set_bounds(0, 1)
fig.legend(loc=(.3375, .9), prop={'size': 12}, ncol=3)
ax.yaxis.set_label_coords(-.1, 0.475)
fig.savefig(fig_dir / 'param_B.pdf')
# Out:
# /Users/morton/PycharmProjects/dcmr/.venv/lib/python3.12/site-packages/mindstorm/statplot.py:188: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.stripplot(data=data, x=x, y=y, hue=hue, ax=ax, **point_prop, **kwargs)
# /Users/morton/PycharmProjects/dcmr/.venv/lib/python3.12/site-packages/mindstorm/statplot.py:203: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.barplot(data=data, x=x, y=y, hue=hue, ax=ax, **bar_prop, **kwargs)
# LINO NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Create parameter tables

# %%
table, orig = reports.create_model_table(
    fit_dir, all_models, all_model_names, model_comp='xval'
)
table.to_latex(fig_dir / 'parameters2_full.tex', escape=False)
table
# Out:
#                                       I              C              D  \
# $\phi_s$                    0.53 (0.08)    0.11 (0.02)    0.36 (0.03)
# $\phi_d$                    1.48 (0.15)    1.30 (0.17)    2.84 (0.18)
# $\beta_{\mathrm{enc}}$      0.70 (0.02)    0.27 (0.04)    0.76 (0.01)
# $\beta_{\mathrm{enc},I}$            ---            ---            ---
# $\beta_{\mathrm{enc},C}$            ---            ---            ---
# $\beta_{\mathrm{enc},D}$            ---            ---            ---
# $\beta_{\mathrm{start}}$    0.49 (0.05)    0.00 (0.00)    0.01 (0.01)
# $\beta_{\mathrm{rec}}$      0.83 (0.01)    0.96 (0.01)    0.91 (0.01)
# $\beta_{\mathrm{rec},I}$            ---            ---            ---
# $\beta_{\mathrm{rec},C}$            ---            ---            ---
# $\beta_{\mathrm{rec},D}$            ---            ---            ---
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                               ---            ---            ---
# $w_2$                               ---            ---            ---
# $s_1$                               ---            ---            ---
# $\tau$                      0.15 (0.02)    0.35 (0.04)    0.28 (0.00)
# $L^{FC}$                            ---            ---            ---
# $L^{FC}_I$                  0.24 (0.04)            ---            ---
# $L^{FC}_C$                          ---    0.77 (0.03)            ---
# $L^{FC}_D$                          ---            ---    0.80 (0.02)
# $L^{CF}$                            ---            ---            ---
# $L^{CF}_I$                  0.25 (0.04)            ---            ---
# $L^{CF}_C$                          ---    0.71 (0.03)            ---
# $L^{CF}_D$                          ---            ---    0.75 (0.02)
# $A^{FF}$                            ---            ---            ---
# $D^{FF}$                            ---            ---            ---
# $k$                                  10             10             10
# $\mathrm{log}(L)$         -32.22 (0.63)  -33.29 (0.55)  -32.11 (0.57)
#
#                                      IC             ID             CD  \
# $\phi_s$                    0.03 (0.01)    0.08 (0.02)    0.13 (0.01)
# $\phi_d$                    1.74 (0.18)    1.63 (0.16)    2.84 (0.18)
# $\beta_{\mathrm{enc}}$      0.52 (0.03)    0.61 (0.02)    0.75 (0.01)
# $\beta_{\mathrm{enc},I}$            ---            ---            ---
# $\beta_{\mathrm{enc},C}$            ---            ---            ---
# $\beta_{\mathrm{enc},D}$            ---            ---            ---
# $\beta_{\mathrm{start}}$    0.66 (0.05)    0.68 (0.05)    0.02 (0.01)
# $\beta_{\mathrm{rec}}$      0.93 (0.01)    0.90 (0.01)    0.95 (0.01)
# $\beta_{\mathrm{rec},I}$            ---            ---            ---
# $\beta_{\mathrm{rec},C}$            ---            ---            ---
# $\beta_{\mathrm{rec},D}$            ---            ---            ---
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.96 (0.01)    0.85 (0.03)    0.10 (0.01)
# $w_2$                               ---            ---            ---
# $s_1$                               ---            ---            ---
# $\tau$                      0.09 (0.02)    0.10 (0.02)    0.36 (0.01)
# $L^{FC}$                            ---            ---            ---
# $L^{FC}_I$                  0.12 (0.03)    0.22 (0.04)            ---
# $L^{FC}_C$                  0.28 (0.02)            ---    0.20 (0.03)
# $L^{FC}_D$                          ---    0.27 (0.03)    0.85 (0.02)
# $L^{CF}$                            ---            ---            ---
# $L^{CF}_I$                  0.13 (0.03)    0.19 (0.04)            ---
# $L^{CF}_C$                  0.05 (0.01)            ---    0.06 (0.02)
# $L^{CF}_D$                          ---    0.31 (0.03)    0.77 (0.02)
# $A^{FF}$                            ---            ---            ---
# $D^{FF}$                            ---            ---            ---
# $k$                                  13             13             13
# $\mathrm{log}(L)$         -30.58 (0.54)  -31.03 (0.58)  -31.75 (0.55)
#
#                                     ICD             UR          RC-RD  \
# $\phi_s$                    0.03 (0.01)    0.02 (0.01)    0.03 (0.01)
# $\phi_d$                    1.72 (0.17)    1.19 (0.16)    1.13 (0.15)
# $\beta_{\mathrm{enc}}$      0.54 (0.02)            ---            ---
# $\beta_{\mathrm{enc},I}$            ---    0.56 (0.02)    0.57 (0.02)
# $\beta_{\mathrm{enc},C}$            ---    0.23 (0.04)    0.24 (0.04)
# $\beta_{\mathrm{enc},D}$            ---    0.46 (0.04)    0.47 (0.04)
# $\beta_{\mathrm{start}}$    0.62 (0.05)    0.68 (0.04)    0.68 (0.04)
# $\beta_{\mathrm{rec}}$      0.93 (0.01)            ---            ---
# $\beta_{\mathrm{rec},I}$            ---    0.80 (0.01)    0.79 (0.01)
# $\beta_{\mathrm{rec},C}$            ---    0.97 (0.02)              1
# $\beta_{\mathrm{rec},D}$            ---    0.91 (0.03)              1
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.96 (0.01)    0.83 (0.03)    0.84 (0.03)
# $w_2$                       0.13 (0.03)    0.21 (0.03)    0.26 (0.04)
# $s_1$                               ---            ---            ---
# $\tau$                      0.12 (0.02)    0.05 (0.01)    0.06 (0.01)
# $L^{FC}$                            ---            ---            ---
# $L^{FC}_I$                  0.17 (0.03)    0.10 (0.03)    0.10 (0.03)
# $L^{FC}_C$                  0.28 (0.03)    0.61 (0.04)    0.60 (0.04)
# $L^{FC}_D$                  0.36 (0.04)    0.62 (0.04)    0.62 (0.04)
# $L^{CF}$                            ---            ---            ---
# $L^{CF}_I$                  0.18 (0.03)    0.09 (0.02)    0.10 (0.02)
# $L^{CF}_C$                  0.07 (0.02)    0.40 (0.04)    0.38 (0.04)
# $L^{CF}_D$                  0.25 (0.04)    0.62 (0.04)    0.60 (0.04)
# $A^{FF}$                            ---            ---            ---
# $D^{FF}$                            ---            ---            ---
# $k$                                  16             20             18
# $\mathrm{log}(L)$         -30.48 (0.54)  -30.26 (0.54)  -30.21 (0.54)
#
#                                    I-CD
# $\phi_s$                    0.59 (0.16)
# $\phi_d$                    1.73 (0.17)
# $\beta_{\mathrm{enc}}$      0.52 (0.02)
# $\beta_{\mathrm{enc},I}$            ---
# $\beta_{\mathrm{enc},C}$            ---
# $\beta_{\mathrm{enc},D}$            ---
# $\beta_{\mathrm{start}}$    0.45 (0.05)
# $\beta_{\mathrm{rec}}$      0.82 (0.01)
# $\beta_{\mathrm{rec},I}$            ---
# $\beta_{\mathrm{rec},C}$            ---
# $\beta_{\mathrm{rec},D}$            ---
# $\theta_s$                  0.01 (0.00)
# $\theta_r$                  0.32 (0.01)
# $w_1$                               ---
# $w_2$                               ---
# $s_1$                       0.39 (0.02)
# $\tau$                      0.08 (0.01)
# $L^{FC}$                    0.10 (0.02)
# $L^{FC}_I$                          ---
# $L^{FC}_C$                          ---
# $L^{FC}_D$                          ---
# $L^{CF}$                    0.10 (0.02)
# $L^{CF}_I$                          ---
# $L^{CF}_C$                          ---
# $L^{CF}_D$                          ---
# $A^{FF}$                    0.07 (0.03)
# $D^{FF}$                    0.13 (0.02)
# $k$                                  13
# $\mathrm{log}(L)$         -30.34 (0.54)

# %%
table, orig = reports.create_model_table(fit_dir, models, model_names, model_comp='xval')
table.to_latex(fig_dir / 'parameters2.tex', escape=False)
table
# Out:
#                                    DCMR  DCMR-Variable   DCMR-Focused  \
# $\phi_s$                    0.03 (0.01)    0.02 (0.01)    0.03 (0.01)
# $\phi_d$                    1.72 (0.17)    1.19 (0.16)    1.13 (0.15)
# $\beta_{\mathrm{enc}}$      0.54 (0.02)            ---            ---
# $\beta_{\mathrm{enc},I}$            ---    0.56 (0.02)    0.57 (0.02)
# $\beta_{\mathrm{enc},C}$            ---    0.23 (0.04)    0.24 (0.04)
# $\beta_{\mathrm{enc},D}$            ---    0.46 (0.04)    0.47 (0.04)
# $\beta_{\mathrm{start}}$    0.62 (0.05)    0.68 (0.04)    0.68 (0.04)
# $\beta_{\mathrm{rec}}$      0.93 (0.01)            ---            ---
# $\beta_{\mathrm{rec},I}$            ---    0.80 (0.01)    0.79 (0.01)
# $\beta_{\mathrm{rec},C}$            ---    0.97 (0.02)              1
# $\beta_{\mathrm{rec},D}$            ---    0.91 (0.03)              1
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.96 (0.01)    0.83 (0.03)    0.84 (0.03)
# $w_2$                       0.13 (0.03)    0.21 (0.03)    0.26 (0.04)
# $s_1$                               ---            ---            ---
# $\tau$                      0.12 (0.02)    0.05 (0.01)    0.06 (0.01)
# $L^{FC}$                            ---            ---            ---
# $L^{FC}_I$                  0.17 (0.03)    0.10 (0.03)    0.10 (0.03)
# $L^{FC}_C$                  0.28 (0.03)    0.61 (0.04)    0.60 (0.04)
# $L^{FC}_D$                  0.36 (0.04)    0.62 (0.04)    0.62 (0.04)
# $L^{CF}$                            ---            ---            ---
# $L^{CF}_I$                  0.18 (0.03)    0.09 (0.02)    0.10 (0.02)
# $L^{CF}_C$                  0.07 (0.02)    0.40 (0.04)    0.38 (0.04)
# $L^{CF}_D$                  0.25 (0.04)    0.62 (0.04)    0.60 (0.04)
# $A^{FF}$                            ---            ---            ---
# $D^{FF}$                            ---            ---            ---
# $k$                                  16             20             18
# $\mathrm{log}(L)$         -30.48 (0.54)  -30.26 (0.54)  -30.21 (0.54)
#
#                                CMR-MP16
# $\phi_s$                    0.59 (0.16)
# $\phi_d$                    1.73 (0.17)
# $\beta_{\mathrm{enc}}$      0.52 (0.02)
# $\beta_{\mathrm{enc},I}$            ---
# $\beta_{\mathrm{enc},C}$            ---
# $\beta_{\mathrm{enc},D}$            ---
# $\beta_{\mathrm{start}}$    0.45 (0.05)
# $\beta_{\mathrm{rec}}$      0.82 (0.01)
# $\beta_{\mathrm{rec},I}$            ---
# $\beta_{\mathrm{rec},C}$            ---
# $\beta_{\mathrm{rec},D}$            ---
# $\theta_s$                  0.01 (0.00)
# $\theta_r$                  0.32 (0.01)
# $w_1$                               ---
# $w_2$                               ---
# $s_1$                       0.39 (0.02)
# $\tau$                      0.08 (0.01)
# $L^{FC}$                    0.10 (0.02)
# $L^{FC}_I$                          ---
# $L^{FC}_C$                          ---
# $L^{FC}_D$                          ---
# $L^{CF}$                    0.10 (0.02)
# $L^{CF}_I$                          ---
# $L^{CF}_C$                          ---
# $L^{CF}_D$                          ---
# $A^{FF}$                    0.07 (0.03)
# $D^{FF}$                    0.13 (0.02)
# $k$                                  13
# $\mathrm{log}(L)$         -30.34 (0.54)

# %%
# %load_ext watermark
# %watermark -v -iv
# Out:
# Python implementation: CPython
# Python version       : 3.12.10
# IPython version      : 9.5.0
#
# dcmr      : 1.0.0a0
# pandas    : 2.3.2
# seaborn   : 0.13.2
# numpy     : 2.1.3
# matplotlib: 3.10.5
# mindstorm : 0.11.2
