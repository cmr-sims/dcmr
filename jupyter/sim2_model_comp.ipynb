# %% [markdown]
# # Plot model fit comparisons for simulation analysis 2

# %%
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from mindstorm import statplot
from dcmr import framework
from dcmr import figures
from dcmr import reports

fit_dir = Path(os.environ['CFR_FITS'])
fig_dir = Path(os.environ['CFR_FIGURES']) / 'sim2'
os.makedirs(fig_dir, exist_ok=True)
figures.set_style()
# %matplotlib inline

# %% [markdown]
# ## Load model fits

# %%
included = ['DCMR-ICD', 'DCMR-Variable', 'DCMR-Focused', 'CMR MP16']
models, model_names = framework.get_sim_models('cfr', 'set2', included=included)
all_models, all_model_names = framework.get_sim_models('cfr', 'set1')

# %% [markdown]
# ## Plot model cross-validation performance

# %%
all_xval = framework.read_model_xvals(fit_dir, all_models, all_model_names)
g = figures.plot_xval_comp(all_xval, aspect=1.3, height=8)
g.savefig(fig_dir / 'model_comp_xval_full.pdf');
# Out:
# LINO NOT subset; don't know how to subset; dropped

# %%
xval = framework.read_model_xvals(fit_dir, models, model_names)
g = figures.plot_xval_comp(xval, aspect=1.57, height=4)
g.savefig(fig_dir / 'model_comp_xval_subset.pdf');
# Out:
# LINO NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Plot best-fitting B parameters by sublayer

# %%
dark = sns.color_palette(
    'ch:start=1, rot=1.5, light=.7, dark=.3, gamma=1, hue=.5'
)
dark
# Out:
# [(0.7689335648950519, 0.6824396172757954, 0.6240123846554909),
#  (0.7250187127782463, 0.5677430873950093, 0.6103083104698684),
#  (0.623013021104788, 0.4855809829815538, 0.6161810850461853),
#  (0.464634733019296, 0.4332443294049108, 0.5801730795425324),
#  (0.31355069957273196, 0.3965359745123169, 0.4760973803152319),
#  (0.2050147315167219, 0.34168808481661433, 0.31762490490999895)]

# %%
light = sns.color_palette(
    'ch:start=1, rot=1.5, light=.7, dark=.3, gamma=.5, hue=1'
)
light
# Out:
# [(0.9248203983802259, 0.8124754066629261, 0.7365856230946308),
#  (0.9370151046580671, 0.7134152392755648, 0.773930517001042),
#  (0.8638347057562072, 0.6485629096614572, 0.8531332480304541),
#  (0.6875944308206159, 0.6323388125763083, 0.8909732355818533),
#  (0.4826946089121227, 0.6491392670198295, 0.8087166257388984),
#  (0.325484389760949, 0.649366831333291, 0.5923429764853889)]

# %%
ur_model = all_models[all_model_names.index("UR")]
fit = framework.read_model_fits(fit_dir, [ur_model], ["UR"])
B_names = [
    'B_enc_loc',
    'B_enc_cat',
    'B_enc_use',
    'B_rec_loc',
    'B_rec_cat',
    'B_rec_use',
]
B_subset = pd.melt(
    fit[B_names].reset_index(),
    id_vars='subject', 
    value_vars=B_names,
    var_name='parameter',
    value_name='value',
)
fit[B_names].reset_index()
# Out:
#    model  subject  B_enc_loc     B_enc_cat  B_enc_use  B_rec_loc  B_rec_cat  \
# 0     UR        1   0.902936  3.308635e-02   0.846900   0.000000   1.000000
# 1     UR        2   0.699122  3.742264e-04   0.854216   0.803054   1.000000
# 2     UR        3   0.653284  3.034603e-02   0.002421   0.747189   1.000000
# 3     UR        5   0.523070  6.253567e-01   0.003237   0.623427   1.000000
# 4     UR        8   0.672541  6.162097e-01   0.591611   0.699485   0.997208
# 5     UR       11   0.190975  0.000000e+00   0.781990   0.200403   1.000000
# 6     UR       16   0.689417  1.353553e-01   0.475161   0.678517   1.000000
# 7     UR       18   0.463827  3.236991e-01   0.000000   0.646318   1.000000
# 8     UR       22   0.656636  2.108392e-01   0.142814   0.711868   1.000000
# 9     UR       23   0.590594  3.301902e-06   0.275770   0.769110   1.000000
# 10    UR       24   0.702315  1.317570e-02   0.926356   0.655787   0.998653
# 11    UR       25   0.405692  3.191156e-07   0.141639   0.676515   1.000000
# 12    UR       27   0.475553  6.529941e-05   0.049463   0.714313   0.163486
# 13    UR       28   0.551453  9.999943e-01   0.064954   0.789757   1.000000
# 14    UR       29   0.610700  1.828615e-02   0.773800   0.719567   1.000000
# 15    UR       31   0.656466  8.154226e-04   0.762094   0.700269   1.000000
# 16    UR       32   0.516026  0.000000e+00   0.684799   0.309796   1.000000
# 17    UR       33   0.585984  1.046464e-01   0.938764   0.669871   1.000000
# 18    UR       34   0.442080  7.787040e-01   0.000000   0.705208   0.000000
# 19    UR       35   0.542330  9.711719e-01   0.000010   0.758754   0.986020
# 20    UR       37   0.861701  1.441286e-05   0.999998   0.957988   0.998913
# 21    UR       38   0.827705  5.723552e-03   0.022537   0.828710   1.000000
# 22    UR       40   0.710307  9.999645e-01   0.700790   0.753739   1.000000
# 23    UR       41   0.515619  1.789258e-04   0.158220   0.761537   1.000000
# 24    UR       42   0.605549  9.948160e-01   0.490518   0.723642   0.999999
# 25    UR       43   0.636129  9.999910e-01   0.911327   0.713355   0.999998
# 26    UR       44   0.595227  3.000882e-04   0.000322   0.717745   1.000000
# 27    UR       45   0.617264  2.157941e-01   0.113897   0.634741   1.000000
# 28    UR       46   0.550752  2.879428e-02   0.034053   0.660595   1.000000
#
#        B_rec_use
# 0   1.000000e+00
# 1   9.977547e-01
# 2   1.000000e+00
# 3   3.387982e-02
# 4   9.999447e-01
# 5   1.000000e+00
# 6   1.000000e+00
# 7   1.000000e+00
# 8   1.000000e+00
# 9   1.000000e+00
# 10  9.773087e-01
# 11  3.424452e-07
# 12  1.000000e+00
# 13  9.999701e-01
# 14  1.000000e+00
# 15  9.999456e-01
# 16  9.788810e-01
# 17  1.000000e+00
# 18  1.000000e+00
# 19  2.179147e-01
# 20  9.999455e-01
# 21  1.000000e+00
# 22  9.951547e-01
# 23  9.999596e-01
# 24  9.997658e-01
# 25  9.999749e-01
# 26  9.999989e-01
# 27  1.000000e+00
# 28  0.000000e+00

# %%
B_labels = [
    r'$\beta_\mathrm{enc}^{I}$',
    r'$\beta_\mathrm{enc}^{C}$',
    r'$\beta_\mathrm{enc}^{D}$',
    r'$\beta_\mathrm{rec}^{I}$',
    r'$\beta_\mathrm{rec}^{C}$',
    r'$\beta_\mathrm{rec}^{D}$',
]
B_subset['phase'] = B_subset['parameter'].map(
    {
        'B_enc_loc': 'enc',
        'B_enc_cat': 'enc',
        'B_enc_use': 'enc',
        'B_rec_loc': 'rec',
        'B_rec_cat': 'rec',
        'B_rec_use': 'rec',
    }
)
B_subset['sublayer'] = B_subset['parameter'].map(
    {
        'B_enc_loc': 'I',
        'B_enc_cat': 'C',
        'B_enc_use': 'D',
        'B_rec_loc': 'I',
        'B_rec_cat': 'C',
        'B_rec_use': 'D',
    }
)
fig, ax = plt.subplots(figsize=(6, 4))
statplot.plot_swarm_bar(
    B_subset,
    x='phase',
    y='value',
    hue='sublayer',
    point_kind='strip',
    light=light,
    dark=dark,
    dodge=True,
    bar_kws={'capsize': 0.2, 'clip_on': False},
    point_kws={'size': 4},
    legend=False,
    ax=ax,
)
ax.set(ylim=(0, 1), ylabel='Parameter estimate')
ax.set_xticks(
    [0, 1], 
    [r'$\beta_{enc}$', r'$\beta_{rec}$'], 
    usetex=True, 
    fontfamily='helvetica',
    fontsize='x-large',
)
ax.tick_params(axis='x', length=0)
ax.set(ylim=(0, 1.08), yticks=np.arange(0, 1.2, 0.2))
ax.spines['left'].set_bounds(0, 1)
fig.legend(loc=(.3375, .9), prop={'size': 12}, ncol=3)
ax.yaxis.set_label_coords(-.1, 0.475)
fig.savefig(fig_dir / 'param_B.pdf')
# Out:
# /Users/morton/VSCode/dcmr/.venv/lib/python3.12/site-packages/mindstorm/statplot.py:188: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.stripplot(data=data, x=x, y=y, hue=hue, ax=ax, **point_prop, **kwargs)
# /Users/morton/VSCode/dcmr/.venv/lib/python3.12/site-packages/mindstorm/statplot.py:203: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.barplot(data=data, x=x, y=y, hue=hue, ax=ax, **bar_prop, **kwargs)
# LINO NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Create parameter tables

# %%
table = reports.create_model_table(fit_dir, all_models, all_model_names, model_comp='xval')
table.to_latex(fig_dir / 'parameters2_full.tex', escape=False)
table
# Out:
#                                       I              C              D  \
# $L_{FC}$                    0.13 (0.01)    0.75 (0.00)    0.61 (0.02)
# $L_{CF}$                    0.11 (0.01)    0.80 (0.01)    0.69 (0.01)
# $D_{FF}$                            ---            ---            ---
# $\phi_s$                    0.39 (0.06)    0.08 (0.00)    0.22 (0.02)
# $\phi_d$                    1.24 (0.13)    0.52 (0.07)    0.35 (0.02)
# $\beta_{\mathrm{enc}}$      0.71 (0.01)    0.04 (0.00)    0.10 (0.01)
# $\beta_{\mathrm{enc},I}$            ---            ---            ---
# $\beta_{\mathrm{enc},C}$            ---            ---            ---
# $\beta_{\mathrm{enc},D}$            ---            ---            ---
# $\beta_{\mathrm{start}}$    0.62 (0.04)    0.00 (0.00)    0.03 (0.01)
# $\beta_{\mathrm{rec}}$      0.78 (0.01)    0.95 (0.01)    0.88 (0.03)
# $\beta_{\mathrm{rec},I}$            ---            ---            ---
# $\beta_{\mathrm{rec},C}$            ---            ---            ---
# $\beta_{\mathrm{rec},D}$            ---            ---            ---
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                               ---            ---            ---
# $w_2$                               ---            ---            ---
# $s_1$                               ---            ---            ---
# $k$                                   9              9              9
# $\mathrm{log}(L)$         -32.43 (0.65)  -33.32 (0.55)  -34.59 (0.63)
#
#                                      IC             ID             CD  \
# $L_{FC}$                    0.10 (0.01)    0.11 (0.01)    0.73 (0.01)
# $L_{CF}$                    0.09 (0.01)    0.10 (0.01)    0.74 (0.01)
# $D_{FF}$                            ---            ---            ---
# $\phi_s$                    0.04 (0.00)    0.08 (0.01)    0.05 (0.00)
# $\phi_d$                    1.81 (0.19)    1.80 (0.18)    0.46 (0.07)
# $\beta_{\mathrm{enc}}$      0.64 (0.01)    0.66 (0.01)    0.05 (0.01)
# $\beta_{\mathrm{enc},I}$            ---            ---            ---
# $\beta_{\mathrm{enc},C}$            ---            ---            ---
# $\beta_{\mathrm{enc},D}$            ---            ---            ---
# $\beta_{\mathrm{start}}$    0.51 (0.04)    0.61 (0.04)    0.01 (0.01)
# $\beta_{\mathrm{rec}}$      0.86 (0.01)    0.84 (0.01)    0.94 (0.02)
# $\beta_{\mathrm{rec},I}$            ---            ---            ---
# $\beta_{\mathrm{rec},C}$            ---            ---            ---
# $\beta_{\mathrm{rec},D}$            ---            ---            ---
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.94 (0.00)    0.83 (0.00)    0.44 (0.02)
# $w_2$                               ---            ---            ---
# $s_1$                               ---            ---            ---
# $k$                                  10             10             10
# $\mathrm{log}(L)$         -30.89 (0.56)  -31.36 (0.60)  -33.15 (0.54)
#
#                                     ICD             UR             EC  \
# $L_{FC}$                    0.10 (0.01)    0.15 (0.02)    0.15 (0.03)
# $L_{CF}$                    0.09 (0.01)    0.14 (0.02)    0.14 (0.03)
# $D_{FF}$                            ---            ---            ---
# $\phi_s$                    0.03 (0.00)    0.07 (0.01)    0.03 (0.00)
# $\phi_d$                    1.84 (0.18)    1.21 (0.16)    1.16 (0.16)
# $\beta_{\mathrm{enc}}$      0.62 (0.01)            ---            ---
# $\beta_{\mathrm{enc},I}$            ---    0.58 (0.02)    0.58 (0.02)
# $\beta_{\mathrm{enc},C}$            ---    0.37 (0.05)              1
# $\beta_{\mathrm{enc},D}$            ---    0.39 (0.04)    0.40 (0.04)
# $\beta_{\mathrm{start}}$    0.50 (0.04)    0.40 (0.04)    0.54 (0.04)
# $\beta_{\mathrm{rec}}$      0.86 (0.01)            ---            ---
# $\beta_{\mathrm{rec},I}$            ---    0.69 (0.02)    0.71 (0.02)
# $\beta_{\mathrm{rec},C}$            ---    0.94 (0.02)    0.97 (0.02)
# $\beta_{\mathrm{rec},D}$            ---    0.85 (0.04)    0.87 (0.03)
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.96 (0.00)    0.91 (0.02)    0.96 (0.00)
# $w_2$                       0.09 (0.01)    0.12 (0.01)    0.12 (0.01)
# $s_1$                               ---            ---            ---
# $k$                                  11             15             14
# $\mathrm{log}(L)$         -30.76 (0.56)  -30.49 (0.56)  -30.49 (0.55)
#
#                                      ED  ...          RC-RD          EC-RC  \
# $L_{FC}$                    0.13 (0.02)  ...    0.13 (0.02)    0.12 (0.02)
# $L_{CF}$                    0.13 (0.02)  ...    0.12 (0.02)    0.11 (0.02)
# $D_{FF}$                            ---  ...            ---            ---
# $\phi_s$                    0.05 (0.00)  ...    0.08 (0.01)    0.03 (0.00)
# $\phi_d$                    1.41 (0.18)  ...    1.23 (0.15)    1.20 (0.16)
# $\beta_{\mathrm{enc}}$              ---  ...            ---            ---
# $\beta_{\mathrm{enc},I}$    0.60 (0.01)  ...    0.58 (0.02)    0.60 (0.02)
# $\beta_{\mathrm{enc},C}$    0.37 (0.04)  ...    0.39 (0.05)              1
# $\beta_{\mathrm{enc},D}$              1  ...    0.42 (0.04)    0.35 (0.04)
# $\beta_{\mathrm{start}}$    0.52 (0.04)  ...    0.42 (0.04)    0.58 (0.04)
# $\beta_{\mathrm{rec}}$              ---  ...            ---            ---
# $\beta_{\mathrm{rec},I}$    0.73 (0.01)  ...    0.71 (0.02)    0.72 (0.02)
# $\beta_{\mathrm{rec},C}$    0.99 (0.01)  ...              1              1
# $\beta_{\mathrm{rec},D}$    0.75 (0.04)  ...              1    0.80 (0.04)
# $\theta_s$                  0.01 (0.00)  ...    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)  ...    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.90 (0.02)  ...    0.93 (0.02)    0.96 (0.00)
# $w_2$                       0.06 (0.01)  ...    0.10 (0.01)    0.13 (0.01)
# $s_1$                               ---  ...            ---            ---
# $k$                                  14  ...             13             13
# $\mathrm{log}(L)$         -30.51 (0.55)  ...  -30.43 (0.55)  -30.48 (0.55)
#
#                                   ED-RD          EC-RD       EC-ED-RC  \
# $L_{FC}$                    0.10 (0.01)    0.12 (0.02)    0.08 (0.01)
# $L_{CF}$                    0.10 (0.01)    0.11 (0.02)    0.08 (0.01)
# $D_{FF}$                            ---            ---            ---
# $\phi_s$                    0.05 (0.00)    0.03 (0.00)    0.02 (0.00)
# $\phi_d$                    1.44 (0.18)    1.14 (0.16)    1.18 (0.16)
# $\beta_{\mathrm{enc}}$              ---            ---            ---
# $\beta_{\mathrm{enc},I}$    0.61 (0.01)    0.60 (0.02)    0.62 (0.01)
# $\beta_{\mathrm{enc},C}$    0.45 (0.04)              1              1
# $\beta_{\mathrm{enc},D}$              1    0.41 (0.04)              1
# $\beta_{\mathrm{start}}$    0.59 (0.04)    0.59 (0.04)    0.69 (0.03)
# $\beta_{\mathrm{rec}}$              ---            ---            ---
# $\beta_{\mathrm{rec},I}$    0.72 (0.01)    0.71 (0.01)    0.74 (0.01)
# $\beta_{\mathrm{rec},C}$    0.98 (0.02)    0.96 (0.02)              1
# $\beta_{\mathrm{rec},D}$              1              1    0.82 (0.04)
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.93 (0.01)    0.96 (0.00)    0.96 (0.00)
# $w_2$                       0.07 (0.01)    0.10 (0.01)    0.07 (0.01)
# $s_1$                               ---            ---            ---
# $k$                                  13             13             12
# $\mathrm{log}(L)$         -30.47 (0.55)  -30.45 (0.55)  -30.47 (0.55)
#
#                                EC-ED-RD       EC-RC-RD       ED-RC-RD  \
# $L_{FC}$                    0.08 (0.01)    0.12 (0.02)    0.09 (0.01)
# $L_{CF}$                    0.08 (0.01)    0.11 (0.02)    0.09 (0.01)
# $D_{FF}$                            ---            ---            ---
# $\phi_s$                    0.02 (0.00)    0.03 (0.00)    0.05 (0.00)
# $\phi_d$                    1.24 (0.17)    1.17 (0.16)    1.37 (0.18)
# $\beta_{\mathrm{enc}}$              ---            ---            ---
# $\beta_{\mathrm{enc},I}$    0.63 (0.01)    0.60 (0.02)    0.60 (0.01)
# $\beta_{\mathrm{enc},C}$              1              1    0.45 (0.04)
# $\beta_{\mathrm{enc},D}$              1    0.39 (0.04)              1
# $\beta_{\mathrm{start}}$    0.71 (0.03)    0.60 (0.04)    0.60 (0.04)
# $\beta_{\mathrm{rec}}$              ---            ---            ---
# $\beta_{\mathrm{rec},I}$    0.73 (0.01)    0.71 (0.01)    0.72 (0.01)
# $\beta_{\mathrm{rec},C}$    0.98 (0.01)              1              1
# $\beta_{\mathrm{rec},D}$              1              1              1
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.96 (0.00)    0.96 (0.00)    0.94 (0.01)
# $w_2$                       0.07 (0.01)    0.10 (0.01)    0.07 (0.01)
# $s_1$                               ---            ---            ---
# $k$                                  12             12             12
# $\mathrm{log}(L)$         -30.46 (0.55)  -30.44 (0.55)  -30.46 (0.55)
#
#                             EC-ED-RC-RD           I-CD
# $L_{FC}$                    0.08 (0.01)    0.08 (0.01)
# $L_{CF}$                    0.08 (0.01)    0.07 (0.01)
# $D_{FF}$                            ---    0.14 (0.00)
# $\phi_s$                    0.02 (0.00)    0.69 (0.14)
# $\phi_d$                    1.29 (0.17)    1.57 (0.15)
# $\beta_{\mathrm{enc}}$              ---    0.62 (0.01)
# $\beta_{\mathrm{enc},I}$    0.63 (0.01)            ---
# $\beta_{\mathrm{enc},C}$              1            ---
# $\beta_{\mathrm{enc},D}$              1            ---
# $\beta_{\mathrm{start}}$    0.71 (0.03)    0.48 (0.04)
# $\beta_{\mathrm{rec}}$              ---    0.75 (0.01)
# $\beta_{\mathrm{rec},I}$    0.73 (0.01)            ---
# $\beta_{\mathrm{rec},C}$              1            ---
# $\beta_{\mathrm{rec},D}$              1            ---
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.96 (0.00)            ---
# $w_2$                       0.07 (0.01)            ---
# $s_1$                               ---    0.38 (0.02)
# $k$                                  11             11
# $\mathrm{log}(L)$         -30.44 (0.55)  -30.43 (0.55)
#
# [21 rows x 24 columns]

# %%
table = reports.create_model_table(fit_dir, models, model_names, model_comp='xval')
table.to_latex(fig_dir / 'parameters2.tex', escape=False)
table
# Out:
#                                DCMR-ICD  DCMR-Variable   DCMR-Focused  \
# $L_{FC}$                    0.10 (0.01)    0.15 (0.02)    0.13 (0.02)
# $L_{CF}$                    0.09 (0.01)    0.14 (0.02)    0.12 (0.02)
# $D_{FF}$                            ---            ---            ---
# $\phi_s$                    0.03 (0.00)    0.07 (0.01)    0.08 (0.01)
# $\phi_d$                    1.84 (0.18)    1.21 (0.16)    1.23 (0.15)
# $\beta_{\mathrm{enc}}$      0.62 (0.01)            ---            ---
# $\beta_{\mathrm{enc},I}$            ---    0.58 (0.02)    0.58 (0.02)
# $\beta_{\mathrm{enc},C}$            ---    0.37 (0.05)    0.39 (0.05)
# $\beta_{\mathrm{enc},D}$            ---    0.39 (0.04)    0.42 (0.04)
# $\beta_{\mathrm{start}}$    0.50 (0.04)    0.40 (0.04)    0.42 (0.04)
# $\beta_{\mathrm{rec}}$      0.86 (0.01)            ---            ---
# $\beta_{\mathrm{rec},I}$            ---    0.69 (0.02)    0.71 (0.02)
# $\beta_{\mathrm{rec},C}$            ---    0.94 (0.02)              1
# $\beta_{\mathrm{rec},D}$            ---    0.85 (0.04)              1
# $\theta_s$                  0.01 (0.00)    0.01 (0.00)    0.01 (0.00)
# $\theta_r$                  0.32 (0.01)    0.32 (0.01)    0.32 (0.01)
# $w_1$                       0.96 (0.00)    0.91 (0.02)    0.93 (0.02)
# $w_2$                       0.09 (0.01)    0.12 (0.01)    0.10 (0.01)
# $s_1$                               ---            ---            ---
# $k$                                  11             15             13
# $\mathrm{log}(L)$         -30.76 (0.56)  -30.49 (0.56)  -30.43 (0.55)
#
#                                CMR MP16
# $L_{FC}$                    0.08 (0.01)
# $L_{CF}$                    0.07 (0.01)
# $D_{FF}$                    0.14 (0.00)
# $\phi_s$                    0.69 (0.14)
# $\phi_d$                    1.57 (0.15)
# $\beta_{\mathrm{enc}}$      0.62 (0.01)
# $\beta_{\mathrm{enc},I}$            ---
# $\beta_{\mathrm{enc},C}$            ---
# $\beta_{\mathrm{enc},D}$            ---
# $\beta_{\mathrm{start}}$    0.48 (0.04)
# $\beta_{\mathrm{rec}}$      0.75 (0.01)
# $\beta_{\mathrm{rec},I}$            ---
# $\beta_{\mathrm{rec},C}$            ---
# $\beta_{\mathrm{rec},D}$            ---
# $\theta_s$                  0.01 (0.00)
# $\theta_r$                  0.32 (0.01)
# $w_1$                               ---
# $w_2$                               ---
# $s_1$                       0.38 (0.02)
# $k$                                  11
# $\mathrm{log}(L)$         -30.43 (0.55)

# %%
# %load_ext watermark
# %watermark -v -iv
# Out:
# Python implementation: CPython
# Python version       : 3.12.10
# IPython version      : 9.2.0
#
# numpy     : 2.1.3
# seaborn   : 0.13.2
# dcmr      : 1.0.0a0
# pandas    : 2.2.3
# matplotlib: 3.10.3
# mindstorm : 0.11.2
