# %% [markdown]
# See here for instructions to set up jupyter lab:
# https://stackoverflow.com/questions/51922480/javascript-error-ipython-is-not-defined-in-jupyterlab

# %%
import os
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from cymr import models
from psifr import fr
from cfr import task
data_file = '/Users/morton/PycharmProjects/cmr_cfr/data/MortEtal13.csv'
sem_file = '/Users/morton/PycharmProjects/cmr_cfr/data/cfr_wikiw2v.mat'
fit_dir = '/Users/morton/Dropbox/work/cfr/test4'
if not os.path.exists(fit_dir):
    os.makedirs(fit_dir)
param_file = '/Users/morton/PycharmProjects/cmr_cfr/fits/test/param_2020-04-25T01:02:03.csv'

# %%
results = pd.read_csv(param_file, index_col=0)
subj_param = results.loc[1]
subj_param
# Out:
# B_rec      0.706104
# Afc        0.000000
# Dfc        4.591694
# Acf        6.084015
# Dcf        7.822870
# Lfc        2.964409
# Lcf        1.829305
# P1         7.444525
# P2         3.486755
# T          1.999996
# X1         0.007863
# X2         0.262239
# B_enc      0.810710
# logl    -901.204434
# Name: 1, dtype: float64

# %%
data = pd.read_csv(data_file)
list_data = data.loc[(data['subject'] == 1) & (data['list'] == 1)]
list_data
# Out:
#     subject  list  position trial_type           item  item_number  session  \
# 0         1     1         1      study          TOWEL          743        1
# 1         1     1         2      study          LADLE          631        1
# 2         1     1         3      study        THERMOS          735        1
# 3         1     1         4      study           LEGO          637        1
# 4         1     1         5      study       BACKPACK          521        1
# 5         1     1         6      study     JACKHAMMER          621        1
# 6         1     1         7      study        LANTERN          633        1
# 7         1     1         8      study       DOORKNOB          576        1
# 8         1     1         9      study         SHOVEL          708        1
# 9         1     1        10      study      WATER GUN          760        1
# 10        1     1        11      study  INK CARTRIDGE          617        1
# 11        1     1        12      study          PHONE          673        1
# 12        1     1        13      study     PAPER CLIP          665        1
# 13        1     1        14      study      MOUSETRAP          657        1
# 14        1     1        15      study        SPEAKER          717        1
# 15        1     1        16      study       CAR SEAT          559        1
# 16        1     1        17      study        BAYONET          532        1
# 17        1     1        18      study         MIRROR          653        1
# 18        1     1        19      study          STONE          724        1
# 19        1     1        20      study          WATCH          759        1
# 20        1     1        21      study           PILL          677        1
# 21        1     1        22      study      SMART CAR          713        1
# 22        1     1        23      study         REMOTE          689        1
# 23        1     1        24      study          CHAIN          561        1
# 24        1     1         1     recall          CHAIN          561        1
# 25        1     1         2     recall      SMART CAR          713        1
# 26        1     1         3     recall        BAYONET          532        1
# 27        1     1         4     recall          WATCH          759        1
# 28        1     1         5     recall       CAR SEAT          559        1
# 29        1     1         6     recall           PILL          677        1
# 30        1     1         7     recall     JACKHAMMER          621        1
# 31        1     1         8     recall          STONE          724        1
# 32        1     1         9     recall         SHOVEL          708        1
# 33        1     1        10     recall       BACKPACK          521        1
# 34        1     1        11     recall       DOORKNOB          576        1
# 35        1     1        12     recall      MOUSETRAP          657        1
# 36        1     1        13     recall          TOWEL          743        1
# 37        1     1        14     recall          CHAIN          561        1
# 38        1     1        15     recall         MIRROR          653        1
# 39        1     1        16     recall          PHONE          673        1
# 40        1     1        17     recall     PAPER CLIP          665        1
# 41        1     1        18     recall           LEGO          637        1
# 42        1     1        19     recall         SHOVEL          708        1
#
#    list_type category  response  response_time list_category
# 0       pure      obj       3.0          1.517           obj
# 1       pure      obj       3.0          1.404           obj
# 2       pure      obj       3.0          0.911           obj
# 3       pure      obj       3.0          0.883           obj
# 4       pure      obj       3.0          0.819           obj
# 5       pure      obj       1.0          1.212           obj
# 6       pure      obj       2.0          0.888           obj
# 7       pure      obj       3.0          0.915           obj
# 8       pure      obj       1.0          1.287           obj
# 9       pure      obj       1.0          0.839           obj
# 10      pure      obj       2.0          0.810           obj
# 11      pure      obj       4.0          0.833           obj
# 12      pure      obj       3.0          0.856           obj
# 13      pure      obj       1.0          0.829           obj
# 14      pure      obj       2.0          0.927           obj
# 15      pure      obj       3.0          0.678           obj
# 16      pure      obj       1.0          0.828           obj
# 17      pure      obj       4.0          0.836           obj
# 18      pure      obj       1.0          0.897           obj
# 19      pure      obj       4.0          0.794           obj
# 20      pure      obj       3.0          0.708           obj
# 21      pure      obj       1.0          1.012           obj
# 22      pure      obj       4.0          0.970           obj
# 23      pure      obj       4.0          0.855           obj
# 24      pure      obj       4.0          0.855           obj
# 25      pure      obj       1.0          1.012           obj
# 26      pure      obj       1.0          0.828           obj
# 27      pure      obj       4.0          0.794           obj
# 28      pure      obj       3.0          0.678           obj
# 29      pure      obj       3.0          0.708           obj
# 30      pure      obj       1.0          1.212           obj
# 31      pure      obj       1.0          0.897           obj
# 32      pure      obj       1.0          1.287           obj
# 33      pure      obj       3.0          0.819           obj
# 34      pure      obj       3.0          0.915           obj
# 35      pure      obj       1.0          0.829           obj
# 36      pure      obj       3.0          1.517           obj
# 37      pure      obj       4.0          0.855           obj
# 38      pure      obj       4.0          0.836           obj
# 39      pure      obj       4.0          0.833           obj
# 40      pure      obj       3.0          0.856           obj
# 41      pure      obj       3.0          0.883           obj
# 42      pure      obj       1.0          1.287           obj

# %%
model = models.CMR()
state_list = model.record_network(list_data, subj_param)

# %%
# %matplotlib widget
from cymr import network
from ipywidgets import interactive
import ipywidgets as widgets
from IPython.display import display

# initialize the plot
fig, ax = network.init_plot()
state = state_list[0]
state[0].plot(ax=ax)

def update(n=1):
    """Update network data on reach time step."""
    print(n)
    ax['c'].images[0].set_data(state[n].c[None, :])
    ax['c_in'].images[0].set_data(state[n].c_in[None, :])
    ax['f'].images[0].set_data(state[n].f[None, :])
    f_in = state[n].f_in
    ax['f_in'].images[0].set_data(f_in[None, :])
    ax['f_in'].images[0].set_clim(np.min(f_in), np.max(f_in))
    ax['w_fc_exp'].images[0].set_data(state[n].w_fc_exp)
    ax['w_cf_exp'].images[0].set_data(state[n].w_cf_exp)

w = interactive(update, n=widgets.IntSlider(min=0, max=len(state) - 1, step=1, value=0))
display(w)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# interactive(children=(IntSlider(value=0, description='n', max=43), Output()), _dom_classes=('widget-interact',…
