# %%
import os
import json
import pandas as pd
import seaborn as sns
res_dir = '/Users/morton/Dropbox/work/cmr_cfr/cfr/fits/test_hybrid_use_rep6_00001'
search_file = os.path.join(res_dir, 'search.csv')
param_file = os.path.join(res_dir, 'parameters.json')

# %%
with open(param_file, 'r') as f:
    param = json.load(f)
search = pd.read_csv(search_file)
free = list(param['free'].keys())

# %%
sns.pairplot(search.filter(free), height=1);
