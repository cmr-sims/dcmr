# %% [markdown]
# # Display an interactive visualization of the network

# %% [markdown]
# See here for instructions to set up jupyter lab:
# https://stackoverflow.com/questions/51922480/javascript-error-ipython-is-not-defined-in-jupyterlab

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
from psifr import fr
from cymr import cmr
from cymr import network

from cfr import framework

cfr_dir = Path(os.environ['CFR_RESULTS'])
fit_dir = Path(os.environ['CFR_FITS'])

model_name = 'cmrs_fcf-loc-cat-use_sl-B_enc-B_rec_fix-B_rec_cat1-B_rec_use1'

# %%
data = pd.read_csv(cfr_dir / 'cfr_eeg_mixed.csv')
patterns = cmr.load_patterns(cfr_dir / 'cfr_patterns.hdf5')
param_def = cmr.read_config(fit_dir / model_name / 'parameters.json')
subj_param = framework.read_fit_param(fit_dir / model_name / 'fit.csv')

# %%
list_data = fr.filter_data(data, subjects=1, lists=2)
list_data
# Out:
#     subject  list  position trial_type                   item  item_index  \
# 0         1     2         1      study              SEAN PENN         228
# 1         1     2         2      study         AUDREY HEPBURN          19
# 2         1     2         3      study  ST PATRICKS CATHEDRAL         463
# 3         1     2         4      study          LES INVALIDES         364
# 4         1     2         5      study   GREAT ZIMBABWE RUINS         340
# 5         1     2         6      study           BRYCE CANYON         281
# 6         1     2         7      study                 TROPHY         745
# 7         1     2         8      study                  BRUSH         548
# 8         1     2         9      study          SUPREME COURT         469
# 9         1     2        10      study          SAN FRANCISCO         444
# 10        1     2        11      study         TREVI FOUNTAIN         483
# 11        1     2        12      study                 TAHITI         472
# 12        1     2        13      study              ANDRE3000          11
# 13        1     2        14      study           NICOLAS CAGE         191
# 14        1     2        15      study      JUSTIN TIMBERLAKE         146
# 15        1     2        16      study          JULIA ROBERTS         144
# 16        1     2        17      study           LEBRON JAMES         159
# 17        1     2        18      study            JOHN MCCAIN         138
# 18        1     2        19      study                  GLASS         596
# 19        1     2        20      study                KLEENEX         627
# 20        1     2        21      study                BLENDER         537
# 21        1     2        22      study                 HELMET         610
# 22        1     2        23      study                  CHAIR         561
# 23        1     2        24      study                  BRICK         546
# 24        1     2         1     recall                  BRICK         546
# 25        1     2         2     recall                  CHAIR         561
# 26        1     2         3     recall          JULIA ROBERTS         144
# 27        1     2         4     recall      JUSTIN TIMBERLAKE         146
# 28        1     2         5     recall              SEAN PENN         228
# 29        1     2         6     recall           LEBRON JAMES         159
# 30        1     2         7     recall            JOHN MCCAIN         138
# 31        1     2         8     recall                  GLASS         596
# 32        1     2         9     recall                 TAHITI         472
# 33        1     2        10     recall          SAN FRANCISCO         444
# 34        1     2        11     recall  ST PATRICKS CATHEDRAL         463
# 35        1     2        12     recall           BRYCE CANYON         281
# 36        1     2        13     recall           NICOLAS CAGE         191
# 37        1     2        14     recall                 TROPHY         745
#
#     session list_type category  response  response_time list_category
# 0         1     mixed      cel       3.0          1.255         mixed
# 1         1     mixed      cel       3.0          1.040         mixed
# 2         1     mixed      loc       2.0          1.164         mixed
# 3         1     mixed      loc       2.0          0.829         mixed
# 4         1     mixed      loc       3.0          0.872         mixed
# 5         1     mixed      loc       2.0          1.241         mixed
# 6         1     mixed      obj       3.0          0.862         mixed
# 7         1     mixed      obj       3.0          0.779         mixed
# 8         1     mixed      loc       2.0          1.245         mixed
# 9         1     mixed      loc       4.0          0.854         mixed
# 10        1     mixed      loc       2.0          1.049         mixed
# 11        1     mixed      loc       4.0          0.824         mixed
# 12        1     mixed      cel       2.0          1.263         mixed
# 13        1     mixed      cel       3.0          0.752         mixed
# 14        1     mixed      cel       4.0          0.898         mixed
# 15        1     mixed      cel       4.0          0.805         mixed
# 16        1     mixed      cel       2.0          0.928         mixed
# 17        1     mixed      cel       2.0          1.018         mixed
# 18        1     mixed      obj       3.0          1.051         mixed
# 19        1     mixed      obj       4.0          0.855         mixed
# 20        1     mixed      obj       2.0          1.171         mixed
# 21        1     mixed      obj       1.0          1.139         mixed
# 22        1     mixed      obj       4.0          0.933         mixed
# 23        1     mixed      obj       1.0          1.043         mixed
# 24        1     mixed      obj       1.0          1.043         mixed
# 25        1     mixed      obj       4.0          0.933         mixed
# 26        1     mixed      cel       4.0          0.805         mixed
# 27        1     mixed      cel       4.0          0.898         mixed
# 28        1     mixed      cel       3.0          1.255         mixed
# 29        1     mixed      cel       2.0          0.928         mixed
# 30        1     mixed      cel       2.0          1.018         mixed
# 31        1     mixed      obj       3.0          1.051         mixed
# 32        1     mixed      loc       4.0          0.824         mixed
# 33        1     mixed      loc       4.0          0.854         mixed
# 34        1     mixed      loc       2.0          1.164         mixed
# 35        1     mixed      loc       2.0          1.241         mixed
# 36        1     mixed      cel       3.0          0.752         mixed
# 37        1     mixed      obj       3.0          0.862         mixed

# %%
model = cmr.CMR()
state = model.record(
    list_data, 
    {}, 
    subj_param, 
    param_def=param_def, 
    patterns=patterns, 
    remove_blank=True,
)

# %%
# %matplotlib widget
from ipywidgets import interactive
import ipywidgets as widgets
from IPython.display import display

# initialize the plot
fig, ax = network.init_plot(figsize=(14, 6))
state[0].plot(ax=ax)

def update(n=1):
    """Update network data on reach time step."""
    ax['c'].images[0].set_data(state[n].c[None, :])
    ax['c_in'].images[0].set_data(state[n].c_in[None, :])
    ax['f'].images[0].set_data(state[n].f[None, :])
    f_in = state[n].f_in
    ax['f_in'].images[0].set_data(f_in[None, :])
    ax['f_in'].images[0].set_clim(np.min(f_in), np.max(f_in))
    ax['w_fc_exp'].images[0].set_data(state[n].w_fc_exp)
    ax['w_cf_exp'].images[0].set_data(state[n].w_cf_exp)

w = interactive(update, n=widgets.IntSlider(min=0, max=len(state) - 1, step=1, value=0))
display(w)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
