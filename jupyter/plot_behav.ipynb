# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pingouin as pg
from psifr import fr
from cfr import task

model_dir = '/Users/morton/Dropbox/work/cmr_cfr/cfr'
data_file = os.path.join(model_dir, 'cfr_eeg_mixed.csv')
fig_dir = '/Users/morton/Dropbox/work/cmr_cfr/cfr/figs/sim1'

# %%
data = task.read_free_recall(data_file, block_category=False)
fr.filter_data(data, subjects=[1], lists=[2])
# Out:
#     subject  list                   item  input  output  study  recall  \
# 0         1     2              SEAN PENN    1.0     5.0   True    True
# 1         1     2         AUDREY HEPBURN    2.0     NaN   True   False
# 2         1     2  ST PATRICKS CATHEDRAL    3.0    11.0   True    True
# 3         1     2          LES INVALIDES    4.0     NaN   True   False
# 4         1     2   GREAT ZIMBABWE RUINS    5.0     NaN   True   False
# 5         1     2           BRYCE CANYON    6.0    12.0   True    True
# 6         1     2                 TROPHY    7.0    14.0   True    True
# 7         1     2                  BRUSH    8.0     NaN   True   False
# 8         1     2          SUPREME COURT    9.0     NaN   True   False
# 9         1     2          SAN FRANCISCO   10.0    10.0   True    True
# 10        1     2         TREVI FOUNTAIN   11.0     NaN   True   False
# 11        1     2                 TAHITI   12.0     9.0   True    True
# ...

# %%
crp = fr.category_crp(data, category_key='category')
sns.displot(data=crp, x='prob');
pg.ttest(crp['prob'], 1/3)
# Out:
#                 T  dof alternative         p-val         CI95%   cohen-d  \
# T-test  24.749254   28   two-sided  1.419818e-20  [0.62, 0.67]  4.595821
#
#              BF10  power
# T-test  2.589e+17    1.0

# %%
crp['prob'].agg(['mean', 'sem'])
# Out:
# mean    0.641477
# sem     0.012451
# Name: prob, dtype: float64
